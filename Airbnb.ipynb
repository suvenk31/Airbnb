# %% [markdown]
# # About this dataset

# %% [markdown]
# This dataset provides a comprehensive look at Airbnb prices in some of the most popular European cities. Each listing is evaluated for various attributes such as room types, cleanliness and satisfaction ratings, bedrooms, distance from the city centre, and more to capture an in-depth understanding of Airbnb prices on both weekdays and weekends. Using spatial econometric methods, we analyse and identify the determinants of Airbnb prices across these cities. Our dataset includes information such as realSum (the total price of the listing), room_type (private/shared/entire home/apt), host_is_superhost (boolean value indicating if host is a superhost or not), multi (indicator whether listing is for multiple rooms or not), biz (business indicator) , guest_satisfaction_overall (overall rating from guests camparing all listings offered by host ), bedrooms, dist (distance from city center) , lng & lat coordinates for location identification etc. We hope that this data set offers insight into how global markets are affected by social dynamics and geographical factors which in turn determine pricing strategies for optimal profitability!

# %%
import pandas as pd

# %%
amsterdamweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
amsterdamweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekends.csv')
athensweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
athensweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\athens_weekends.csv')
barcelonaweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
barcelonaweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\barcelona_weekends.csv')
berlinweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
berlinweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\berlin_weekends.csv')
budapestweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
budapestweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\budapest_weekends.csv')
lisbonweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
lisbonweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\lisbon_weekends.csv')
londonweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
londonweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\london_weekends.csv')
parisweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
parisweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\paris_weekends.csv')
romeweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
romeweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\rome_weekends.csv')
viennaweekdays =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\amsterdam_weekdays.csv')
viennaweekends  =pd.read_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\vienna_weekends.csv')

# %%
viennaweekends.head()
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  324.661665  Entire home/apt        False         False
# 1           1  150.760816  Entire home/apt        False         False
# 2           2  196.339668  Entire home/apt        False         False
# 3           3  107.753079     Private room        False          True
# 4           4  196.339668  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              4.0               True      0    1                10.0  ...
# 1              2.0               True      0    1                10.0  ...
# 2              3.0               True      0    1                 9.0  ...
# 3              2.0              False      0    0                 8.0  ...
# 4              4.0               True      0    1                 9.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
viennaweekends[['Country','Days']] = ['Vienna','Weekend']
viennaweekdays[['Country','Days']] = ['Amsterdam','Weekday']
amsterdamweekends[['Country','Days']] = ['Amsterdam','Weekend']
amsterdamweekdays[['Country','Days']] = ['Amsterdam','Weekday']
romeweekends[['Country','Days']] = ['Rome','Weekend']
romeweekdays[['Country','Days']] = ['Rome','Weekday']
londonweekends[['Country','Days']] = ['London','Weekend']
londonweekdays[['Country','Days']] = ['London','Weekday']
lisbonweekends[['Country','Days']] = ['Lisbon','Weekend']
lisbonweekdays[['Country','Days']] = ['Lisbon','Weekday']
athensweekends[['Country','Days']] = ['Athens','Weekend']
athensweekdays[['Country','Days']] = ['Athens','Weekday']
barcelonaweekends[['Country','Days']] = ['Barcelona','Weekend']
barcelonaweekdays[['Country','Days']] = ['Barcelona','Weekday']
parisweekends[['Country','Days']] = ['Paris','Weekend']
parisweekdays[['Country','Days']] = ['Paris','Weekday']
budapestweekends[['Country','Days']] = ['Budapest','Weekend']
budapestweekdays[['Country','Days']] = ['Budapest','Weekday']
berlinweekends[['Country','Days']] = ['Berlin','Weekend']
berlinweekdays[['Country','Days']] = ['Berlin','Weekday']

# %%
alldata = pd.concat([viennaweekdays,
amsterdamweekends,
amsterdamweekdays,
romeweekends,
romeweekdays,
londonweekends,
londonweekdays,
lisbonweekends,
lisbonweekdays,
athensweekends,
athensweekdays,
barcelonaweekends,
barcelonaweekdays,
parisweekends,
parisweekdays,
budapestweekends,
budapestweekdays,
berlinweekends,
berlinweekdays,
viennaweekends
])

# %%
alldata.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
alldata.to_csv('C:\\Users\\SV87336\\Desktop\\Project\\Data\\Airbnb\\Airbnb.csv',index=False)
